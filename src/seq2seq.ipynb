# %%
import pandas as pd

# %% [markdown]
# ## Read dataset

# %%
df = pd.read_csv('../../WikiHow-Dataset/wikihowAll.csv', delimiter=',')

# %%
df.head()
# Out:
#                                             headline  \
# 0  \nKeep related supplies in the same area.,\nMa...
# 1  \nCreate a sketch in the NeoPopRealist manner ...
# 2  \nGet a bachelor’s degree.,\nEnroll in a studi...
# 3  \nStart with some experience or interest in ar...
# 4  \nKeep your reference materials, sketches, art...
#
#                                     title  \
# 0          How to Be an Organized Artist1
# 1  How to Create a Neopoprealist Art Work
# 2      How to Be a Visual Effects Artist1
# 3           How to Become an Art Investor
# 4          How to Be an Organized Artist2
#
#                                                 text
# 0   If you're a photographer, keep all the necess...
# 1   See the image for how this drawing develops s...
# 2   It is possible to become a VFX artist without...
# 3   The best art investors do their research on t...
# 4   As you start planning for a project or work, ...

# %%
df['summary'] = df['title'].str.cat(df['headline'], sep='')
df=df.dropna()

# %%
prepare_df = pd.DataFrame()
prepare_df['summary'] = df['summary']
prepare_df['text'] = df['text']

prepare_df.head()
# Out:
#                                              summary  \
# 0  How to Be an Organized Artist1\nKeep related s...
# 1  How to Create a Neopoprealist Art Work\nCreate...
# 2  How to Be a Visual Effects Artist1\nGet a bach...
# 3  How to Become an Art Investor\nStart with some...
# 4  How to Be an Organized Artist2\nKeep your refe...
#
#                                                 text
# 0   If you're a photographer, keep all the necess...
# 1   See the image for how this drawing develops s...
# 2   It is possible to become a VFX artist without...
# 3   The best art investors do their research on t...
# 4   As you start planning for a project or work, ...

# %% [markdown]
# ## Clean the data

# %%
import re

# Remove non-alphabetic characters (Data Cleaning)
def text_strip(column):
    for row in column:
        row = re.sub("(\\t)", " ", str(row)).lower()
        row = re.sub("(\\r)", " ", str(row)).lower()
        row = re.sub("(\\n)", " ", str(row)).lower()

        # Remove _ if it occurs more than one time consecutively
        row = re.sub("(__+)", " ", str(row)).lower()

        # Remove - if it occurs more than one time consecutively
        row = re.sub("(--+)", " ", str(row)).lower()

        # Remove ~ if it occurs more than one time consecutively
        row = re.sub("(~~+)", " ", str(row)).lower()

        # Remove + if it occurs more than one time consecutively
        row = re.sub("(\+\++)", " ", str(row)).lower()

        # Remove . if it occurs more than one time consecutively
        row = re.sub("(\.\.+)", " ", str(row)).lower()

        # Remove the characters - <>()|&©ø"',;?~*!
        row = re.sub(r"[<>()|&©ø\[\]\'\",;?~*!]", " ", str(row)).lower()

        # Remove punctuations at the end of a word
        row = re.sub("(\.\s+)", " ", str(row)).lower()
        row = re.sub("(\-\s+)", " ", str(row)).lower()
        row = re.sub("(\:\s+)", " ", str(row)).lower()

        # Replace any url to only the domain name
        try:
            url = re.search(r"((https*:\/*)([^\/\s]+))(.[^\s]+)", str(row))
            repl_url = url.group(3)
            row = re.sub(r"((https*:\/*)([^\/\s]+))(.[^\s]+)", repl_url, str(row))
        except:
            pass

        # Remove multiple spaces
        row = re.sub("(\s+)", " ", str(row)).lower()

        # Remove the single character hanging between any two spaces
        row = re.sub("(\s+.\s+)", " ", str(row)).lower()

        yield row

# %%
processed_text = text_strip(prepare_df['summary'])
processed_summary = text_strip(prepare_df['text'])

# %%
prepare_df.head()
# Out:
#                                              summary  \
# 0  How to Be an Organized Artist1\nKeep related s...
# 1  How to Create a Neopoprealist Art Work\nCreate...
# 2  How to Be a Visual Effects Artist1\nGet a bach...
# 3  How to Become an Art Investor\nStart with some...
# 4  How to Be an Organized Artist2\nKeep your refe...
#
#                                                 text
# 0   If you're a photographer, keep all the necess...
# 1   See the image for how this drawing develops s...
# 2   It is possible to become a VFX artist without...
# 3   The best art investors do their research on t...
# 4   As you start planning for a project or work, ...

# %%
import spacy
from time import time

nlp = spacy.load('en_core_web_sm', disable=['ner', 'parser']) 

# Process text as batches and yield Doc objects in order
text = [str(doc) for doc in nlp.pipe(processed_text, batch_size=5000)]

summary = ['_START_ '+ str(doc) + ' _END_' for doc in nlp.pipe(processed_summary, batch_size=5000)]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 7
#       4 nlp = spacy.load('en_core_web_sm', disable=['ner', 'parser'])
#       6 # Process text as batches and yield Doc objects in order
# ----> 7 text = [str(doc) for doc in nlp.pipe(processed_text, batch_size=5000)]
#       9 summary = ['_START_ '+ str(doc) + ' _END_' for doc in nlp.pipe(processed_summary, batch_size=5000)]
#
# Cell In[9], line 7, in <listcomp>(.0)
#       4 nlp = spacy.load('en_core_web_sm', disable=['ner', 'parser'])
#       6 # Process text as batches and yield Doc objects in order
# ----> 7 text = [str(doc) for doc in nlp.pipe(processed_text, batch_size=5000)]
#       9 summary = ['_START_ '+ str(doc) + ' _END_' for doc in nlp.pipe(processed_summary, batch_size=5000)]
#
# File ~\Documents\Git\text-summarization\venv\lib\site-packages\spacy\language.py:1574, in Language.pipe(self, texts, as_tuples, batch_size, disable, component_cfg, n_process)
#    1572     for pipe in pipes:
#    1573         docs = pipe(docs)
# -> 1574 for doc in docs:
#    1575     yield doc
#
# File ~\Documents\Git\text-summarization\venv\lib\site-packages\spacy\util.py:1653, in _pipe(docs, proc, name, default_error_handler, kwargs)
#    1643 def _pipe(
#    1644     docs: Iterable["Doc"],
#    1645     proc: "PipeCallable",
#    (...)
#    1650     kwargs: Mapping[str, Any],
#    1651 ) -> Iterator["Doc"]:
#    1652     if hasattr(proc, "pipe"):
# -> 1653         yield from proc.pipe(docs, **kwargs)
#    1654     else:
#    1655         # We added some args for pipe that __call__ doesn't expect.
#    1656         kwargs = dict(kwargs)
#
# File ~\Documents\Git\text-summarization\venv\lib\site-packages\spacy\pipeline\pipe.pyx:53, in pipe()
#
# File ~\Documents\Git\text-summarization\venv\lib\site-packages\spacy\util.py:1653, in _pipe(docs, proc, name, default_error_handler, kwargs)
#    1643 def _pipe(
#    1644     docs: Iterable["Doc"],
#    1645     proc: "PipeCallable",
#    (...)
#    1650     kwargs: Mapping[str, Any],
#    1651 ) -> Iterator["Doc"]:
#    1652     if hasattr(proc, "pipe"):
# -> 1653         yield from proc.pipe(docs, **kwargs)
#    1654     else:
#    1655         # We added some args for pipe that __call__ doesn't expect.
#    1656         kwargs = dict(kwargs)
#
# File ~\Documents\Git\text-summarization\venv\lib\site-packages\spacy\pipeline\pipe.pyx:53, in pipe()
#
# File ~\Documents\Git\text-summarization\venv\lib\site-packages\spacy\util.py:1653, in _pipe(docs, proc, name, default_error_handler, kwargs)
#    1643 def _pipe(
#    1644     docs: Iterable["Doc"],
#    1645     proc: "PipeCallable",
#    (...)
#    1650     kwargs: Mapping[str, Any],
#    1651 ) -> Iterator["Doc"]:
#    1652     if hasattr(proc, "pipe"):
# -> 1653         yield from proc.pipe(docs, **kwargs)
#    1654     else:
#    1655         # We added some args for pipe that __call__ doesn't expect.
#    1656         kwargs = dict(kwargs)
#
# File ~\Documents\Git\text-summarization\venv\lib\site-packages\spacy\pipeline\trainable_pipe.pyx:73, in pipe()
#
# File ~\Documents\Git\text-summarization\venv\lib\site-packages\spacy\util.py:1600, in minibatch(items, size)
#    1598 while True:
#    1599     batch_size = next(size_)
# -> 1600     batch = list(itertools.islice(items, int(batch_size)))
#    1601     if len(batch) == 0:
#    1602         break
#
# File ~\Documents\Git\text-summarization\venv\lib\site-packages\spacy\util.py:1653, in _pipe(docs, proc, name, default_error_handler, kwargs)
#    1643 def _pipe(
#    1644     docs: Iterable["Doc"],
#    1645     proc: "PipeCallable",
#    (...)
#    1650     kwargs: Mapping[str, Any],
#    1651 ) -> Iterator["Doc"]:
#    1652     if hasattr(proc, "pipe"):
# -> 1653         yield from proc.pipe(docs, **kwargs)
#    1654     else:
#    1655         # We added some args for pipe that __call__ doesn't expect.
#    1656         kwargs = dict(kwargs)
#
# File ~\Documents\Git\text-summarization\venv\lib\site-packages\spacy\pipeline\trainable_pipe.pyx:75, in pipe()
#
# File ~\Documents\Git\text-summarization\venv\lib\site-packages\spacy\pipeline\tok2vec.py:125, in Tok2Vec.predict(self, docs)
#     123     width = self.model.get_dim("nO")
#     124     return [self.model.ops.alloc((0, width)) for doc in docs]
# --> 125 tokvecs = self.model.predict(docs)
#     126 return tokvecs
#
# File ~\Documents\Git\text-summarization\venv\lib\site-packages\thinc\model.py:315, in Model.predict(self, X)
#     311 def predict(self, X: InT) -> OutT:
#     312     """Call the model's `forward` function with `is_train=False`, and return
#     313     only the output, instead of the `(output, callback)` tuple.
#     314     """
# --> 315     return self._func(self, X, is_train=False)[0]
#
# File ~\Documents\Git\text-summarization\venv\lib\site-packages\thinc\layers\chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File ~\Documents\Git\text-summarization\venv\lib\site-packages\thinc\model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~\Documents\Git\text-summarization\venv\lib\site-packages\thinc\layers\with_array.py:38, in forward(model, Xseq, is_train)
#      36     return model.layers[0](Xseq, is_train)
#      37 else:
# ---> 38     return cast(Tuple[SeqT, Callable], _list_forward(model, Xseq, is_train))
#
# File ~\Documents\Git\text-summarization\venv\lib\site-packages\thinc\layers\with_array.py:73, in _list_forward(model, Xs, is_train)
#      71 lengths = layer.ops.asarray1i([len(seq) for seq in Xs])
#      72 Xf = layer.ops.flatten(Xs, pad=pad)
# ---> 73 Yf, get_dXf = layer(Xf, is_train)
#      75 def backprop(dYs: ListXd) -> ListXd:
#      76     dYf = layer.ops.flatten(dYs, pad=pad)
#
# File ~\Documents\Git\text-summarization\venv\lib\site-packages\thinc\model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~\Documents\Git\text-summarization\venv\lib\site-packages\thinc\layers\chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File ~\Documents\Git\text-summarization\venv\lib\site-packages\thinc\model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~\Documents\Git\text-summarization\venv\lib\site-packages\thinc\layers\residual.py:41, in forward(model, X, is_train)
#      38     else:
#      39         return d_output + dX
# ---> 41 Y, backprop_layer = model.layers[0](X, is_train)
#      42 if isinstance(X, list):
#      43     return [X[i] + Y[i] for i in range(len(X))], backprop
#
# File ~\Documents\Git\text-summarization\venv\lib\site-packages\thinc\model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~\Documents\Git\text-summarization\venv\lib\site-packages\thinc\layers\chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File ~\Documents\Git\text-summarization\venv\lib\site-packages\thinc\model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~\Documents\Git\text-summarization\venv\lib\site-packages\thinc\layers\chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
#     [... skipping similar frames: Model.__call__ at line 291 (1 times)]
#
# File ~\Documents\Git\text-summarization\venv\lib\site-packages\thinc\layers\chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File ~\Documents\Git\text-summarization\venv\lib\site-packages\thinc\model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~\Documents\Git\text-summarization\venv\lib\site-packages\thinc\layers\maxout.py:53, in forward(model, X, is_train)
#      51 W = model.get_param("W")
#      52 W = model.ops.reshape2f(W, nO * nP, nI)
# ---> 53 Y = model.ops.gemm(X, W, trans2=True)
#      54 Y += model.ops.reshape1f(b, nO * nP)
#      55 Z = model.ops.reshape3f(Y, Y.shape[0], nO, nP)
#
# KeyboardInterrupt:
